# %% [markdown]
# # Guia de Introdução ao NumPy
#
# NumPy, que significa Numerical Python, é uma biblioteca fundamental para a computação científica em Python. Ela fornece suporte para arrays e matrizes, além de funções matemáticas para operações com esses objetos. É, também, a base da biblioteca Pandas.

# %% [markdown]
# ## Instalação
#
# Para instalar o NumPy, você pode usar o pip, que é o gerenciador de pacotes do Python.
#
# ```python
# pip install numpy
# ```
#
# ## Arrays
#
# Um array é uma estrutura de dados que armazena valores do mesmo tipo. Em Python, isso é uma grande vantagem porque economiza espaço e permite operações mais eficientes. Vamos criar um array.

# %%
import numpy as np

array = np.array(['a','b','c','d','e'])

print (array)
# Out:
# ['a' 'b' 'c' 'd' 'e']

# %%
#indexação
print (array[0])
print (array[-1])
print (array[-3])

#slicing => Para entender o primeiro indice é incluso e o último excluso, por isto não veio a letra e
print (array[1:4])
print (array[0:-1]) # A letra e foi excluída pq -1 significa o último elemento do array
print (array[0:-1:2]) # O parametro 2 é o step, ou seja, vai de 2 em 2
print (array[0::2])
print (array[::2])
print (array[::])
print (array[:])
print (array[::-1]) #Lê o array de trás pra frente
print (array[::-2])
# Out:
# a
# e
# c
# ['b' 'c' 'd']
# ['a' 'b' 'c' 'd']
# ['a' 'c']
# ['a' 'c' 'e']
# ['a' 'c' 'e']
# ['a' 'b' 'c' 'd' 'e']
# ['a' 'b' 'c' 'd' 'e']
# ['e' 'd' 'c' 'b' 'a']
# ['e' 'c' 'a']
